# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\suyas\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\suyas\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\suyas\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[6,7,8,9]
plt.plot(x,y,label="she")
a=[3,6,2,10]
b=[2,4,12,3]
plt.plot(a,b,label="hee")
plt.show()
plt.title("defrg")
plt.xlabel("Hello")
plt.ylabel("learning")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy  as np
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]
non_oscar_movies = [
    "Slumdog Millionaire",
    "Avatar",
    "Inception",
    "Hugo",
    "Lincoln"
]


non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.title("Oscar vs Non oscar movies revenue")
plt.xlabel("years")
x=np.arange(len(years))
plt.ylabel("Revenues")
width=0.35
plt.bar(x-width/2,oscar_revenue,width,label="oscar")

plt.bar(x+width/2,non_oscar_revenue,width,label="non_oscar")
plt.xlabel("years")
plt.ylabel("revenue")

plt.legend()
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x25dbf49fb30>,
#   <matplotlib.axis.XTick at 0x25dbf4bf5f0>,
#   <matplotlib.axis.XTick at 0x25dbf49c110>,
#   <matplotlib.axis.XTick at 0x25dbf670950>,
#   <matplotlib.axis.XTick at 0x25dbf6712b0>],
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])
