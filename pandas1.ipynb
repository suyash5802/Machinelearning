# %%
# !pip install pandas

# %%
import pandas as pd

df=pd.read_csv("globalAirQuality.csv")

# %%
df["aqi"]
# Out:
# 0        108
# 1         90
# 2         84
# 3        158
# 4         97
#         ...
# 17995    103
# 17996    105
# 17997    122
# 17998     95
# 17999     88
# Name: aqi, Length: 18000, dtype: int64

# %%
df[["city","aqi",]]
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
df.loc[0:2]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650

# %%
df.loc[0:2,["city","aqi","no2"]]
# Out:
#        city  aqi     no2
# 0  New York  108  27.998
# 1  New York   90  36.120
# 2  New York   84  26.935

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
#filtering of data
df[df["aqi"]>120]
df[(df["aqi"]>120) & (df["temperature"]>35)].head()
# Out:
#                       timestamp country      city  latitude  longitude  \
# 6    2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 17   2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 82   2025-11-08 04:25:17.554219      US  New York    40.713    -74.006
# 105  2025-11-09 03:25:17.554219      US  New York    40.713    -74.006
# 182  2025-11-12 08:25:17.554219      US  New York    40.713    -74.006
#
#        pm25    pm10     no2     so2      o3     co  aqi  temperature  \
# 6    77.690  65.198  20.302   7.641  62.687  0.734  155       36.729
# 17   63.552  57.838  13.754   4.427  42.251  0.997  127       36.193
# 82   40.081  98.158  48.832   3.014  70.108  0.852  122       36.859
# 105  63.994  67.237  37.392   8.483  40.692  0.725  127       36.977
# 182  66.706  36.434  14.805  11.517  58.370  0.664  133       37.694
#
#      humidity  wind_speed
# 6      47.651       4.542
# 17     62.906       7.097
# 82     86.703       9.652
# ...

# %%
aqi_data=df[(df["aqi"]>120) & (df["temperature"]>35)][["city","aqi"]]
aqi_data.iloc(1)

# %%
aqi_data.iloc[1]

#query
df.query("aqi>112 & temperature>30")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17881  2025-11-14 19:25:17.554219      CH    Zurich    47.377      8.542
# 17883  2025-11-14 21:25:17.554219      CH    Zurich    47.377      8.542
# 17940  2025-11-17 06:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...
