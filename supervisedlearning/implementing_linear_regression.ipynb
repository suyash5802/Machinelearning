# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\suyas\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\suyas\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\suyas\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\suyas\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\suyas\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\suyas\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np
import pandas as pd

# %%
class LinearRegression:
    def __init__(self,Lr=0.1,n_iter=1000):
        self.bias=None
        self.weights=None
        self.lr=Lr
        self.n_iter=n_iter
    
    def fit(self,X,y):
        m,n=X.shape # (number of samples, number of features)
        self.bias=0
        self.weigts=np.zeros(n)
        for i in range(self.n_iter):
            y_pred = self.bias + np.dot(X, self.weights)
    
            # STEP3 - calc gradient
            db = (1/m) * np.sum(y_pred - y)
            dw = (1/m) * np.dot(X.T, (y_pred - y))
    
            # STEP4 - convergence theorem - params update
            self.bias -= self.lr * db
            self.weights -= self.lr * dw

    def predict(self, X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
print(y_pred)

print(model.bias)
print(model.weights)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 y = np.array([2, 4, 6, 8, 10])
#       4 model = LinearRegression()
# ----> 5 model.fit(X, y)
#       7 y_pred = model.predict(X)
#       8 print(y_pred)
#
# Cell In[3], line 13, in LinearRegression.fit(self, X, y)
#      11 self.weigts=np.zeros(n)
#      12 for i in range(self.n_iter):
# ---> 13     y_pred = self.bias + np.dot(X, self.weights)
#      15     # STEP3 - calc gradient
#      16     db = (1/m) * np.sum(y_pred - y)
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'
